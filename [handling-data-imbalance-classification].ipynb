# %%
# Libaries

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

from sklearn.feature_selection import RFE
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.api as sm
from statsmodels.formula.api import ols

from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks

# %% [markdown]
# # 1. Read datasets

# %%
numerical = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\15_Revision_and_Hypothesis-Testing\numerical.csv")
targets = pd.read_csv(r"C:\Users\ljant\Desktop\Ironhack\15_Revision_and_Hypothesis-Testing\target.csv")
donors = pd.concat([numerical, targets], axis = 1)
donors
# Out:
#        TCODE        AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  VIETVETS  \
# 0          0  60.000000       5        9    0         0       39        34
# 1          1  46.000000       6        9   16         0       15        55
# 2          1  61.611649       3        1    2         0       20        29
# 3          0  70.000000       1        4    2         0       23        14
# 4          0  78.000000       3        2   60         1       28         9
# ...      ...        ...     ...      ...  ...       ...      ...       ...
# 95407      1  61.611649       5        9    0        14       36        47
# 95408      1  48.000000       7        9    1         0       31        43
# 95409      1  60.000000       5        9    0         0       18        46
# 95410      0  58.000000       7        9    0         0       28        35
# 95411      2  80.000000       5        8    3         1       33        22
#
#        WWIIVETS  LOCALGOV  ...  MAXRAMNT  LASTGIFT  TIMELAG    AVGGIFT  \
# 0            18        10  ...      12.0      10.0        4   7.741935
# 1            11         6  ...      25.0      25.0       18  15.666667
# 2            33         6  ...      16.0       5.0       12   7.481481
# 3            31         3  ...      11.0      10.0        9   6.812500
# 4            53        26  ...      15.0      15.0       14   6.864865
# ...         ...       ...  ...       ...       ...      ...        ...
# 95407        11         7  ...      25.0      25.0        9  25.000000
# 95408        19         4  ...      20.0      20.0        9  20.000000
# 95409        20         7  ...      10.0      10.0        3   8.285714
# 95410        20         9  ...      21.0      18.0        4  12.146341
# 95411        27         8  ...     201.0     100.0        6  96.794872
#
#        CONTROLN  HPHONE_D  RFA_2F  CLUSTER2  TARGET_B  TARGET_D
# 0         95515         0       4        39         0       0.0
# 1        148535         0       2         1         0       0.0
# 2         15078         1       4        60         0       0.0
# 3        172556         1       4        41         0       0.0
# 4          7112         1       2        26         0       0.0
# ...         ...       ...     ...       ...       ...       ...
# 95407    184568         0       1        12         0       0.0
# 95408    122706         1       1         2         0       0.0
# 95409    189641         1       3        34         0       0.0
# 95410      4693         1       4        11         1      18.0
# 95411    185114         1       1        12         0       0.0
#
# [95412 rows x 317 columns]

# %%
def header_function (data):
    cols = []
    for i in range (len(data.columns)):
        cols.append(data.columns[i].lower().replace(' ','_'))
    
    data.columns = cols

    return data

header_function(donors)
# Out:
#        tcode        age  income  wealth1  hit  malemili  malevet  vietvets  \
# 0          0  60.000000       5        9    0         0       39        34
# 1          1  46.000000       6        9   16         0       15        55
# 2          1  61.611649       3        1    2         0       20        29
# 3          0  70.000000       1        4    2         0       23        14
# 4          0  78.000000       3        2   60         1       28         9
# ...      ...        ...     ...      ...  ...       ...      ...       ...
# 95407      1  61.611649       5        9    0        14       36        47
# 95408      1  48.000000       7        9    1         0       31        43
# 95409      1  60.000000       5        9    0         0       18        46
# 95410      0  58.000000       7        9    0         0       28        35
# 95411      2  80.000000       5        8    3         1       33        22
#
#        wwiivets  localgov  ...  maxramnt  lastgift  timelag    avggift  \
# 0            18        10  ...      12.0      10.0        4   7.741935
# 1            11         6  ...      25.0      25.0       18  15.666667
# 2            33         6  ...      16.0       5.0       12   7.481481
# 3            31         3  ...      11.0      10.0        9   6.812500
# 4            53        26  ...      15.0      15.0       14   6.864865
# ...         ...       ...  ...       ...       ...      ...        ...
# 95407        11         7  ...      25.0      25.0        9  25.000000
# 95408        19         4  ...      20.0      20.0        9  20.000000
# 95409        20         7  ...      10.0      10.0        3   8.285714
# 95410        20         9  ...      21.0      18.0        4  12.146341
# 95411        27         8  ...     201.0     100.0        6  96.794872
#
#        controln  hphone_d  rfa_2f  cluster2  target_b  target_d
# 0         95515         0       4        39         0       0.0
# 1        148535         0       2         1         0       0.0
# 2         15078         1       4        60         0       0.0
# 3        172556         1       4        41         0       0.0
# 4          7112         1       2        26         0       0.0
# ...         ...       ...     ...       ...       ...       ...
# 95407    184568         0       1        12         0       0.0
# 95408    122706         1       1         2         0       0.0
# 95409    189641         1       3        34         0       0.0
# 95410      4693         1       4        11         1      18.0
# 95411    185114         1       1        12         0       0.0
#
# [95412 rows x 317 columns]

# %% [markdown]
# # 2. Clean data

# %% [markdown]
# 2.1 Get numerical data

# %%
data_types = donors.dtypes
print (data_types)

cat_columns = data_types[data_types == 'object']
print("Non-numeric columns:\n", cat_columns)

# Result: No non-numeric columns
# Out:
# tcode         int64
# age         float64
# income        int64
# wealth1       int64
# hit           int64
#              ...
# hphone_d      int64
# rfa_2f        int64
# cluster2      int64
# target_b      int64
# target_d    float64
# Length: 317, dtype: object
# Non-numeric columns:
#  Series([], dtype: object)

# %% [markdown]
# 2.2. Dealing with NaNs

# %%
sum_na = donors.isna().sum()
print (sum_na)

nan_columns = sum_na[sum_na != 0]
print('Columns with NaN values:\n', nan_columns)

# Result: No columns with NaN values
# Out:
# tcode       0
# age         0
# income      0
# wealth1     0
# hit         0
#            ..
# hphone_d    0
# rfa_2f      0
# cluster2    0
# target_b    0
# target_d    0
# Length: 317, dtype: int64
# Columns with NaN values:
#  Series([], dtype: int64)

# %% [markdown]
# # 3. Train-Test-Split

# %%
X = donors.drop(['target_b', 'target_d'], axis = 1)
Y = donors['target_b']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # 4. Logistic regression model

# %%
model_b = LogisticRegression()
model_b.fit(X_train, Y_train)
result = model_b.score(X_train, Y_train)
print("The accuracy of the model is = ", round(result,2))

# Accuracy of the model is 95 %
# Out:
# The accuracy of the model is =  0.95

# %%
# Selecting only relevant columns (RFE)

lm = linear_model.LinearRegression()
rfe = RFE(lm, n_features_to_select = 10)
rfe.fit(X_train,Y_train)

# After running it, it labels the top features as 1
df = pd.DataFrame(rfe.ranking_, columns=['Rank'])
df['Column_name'] = X_train.columns
df[df['Rank']==1]
# Out:
#      Rank Column_name
# 3       1      income
# 20      1     pop90c4
# 21      1     pop90c5
# 31      1       eth10
# 77      1         dw3
# 79      1         dw5
# 81      1         dw7
# 82      1         dw8
# 83      1         dw9
# 97      1        hhd5
# 98      1        hhd6
# 105     1       ethc1
# 123     1       hupa1
# 124     1       hupa2
# 169     1        tpe3
# 170     1        tpe4
# 171     1        tpe5
# 172     1        tpe6
# 289     1        hc15
# 314     1      rfa_2f

# %%
# Assigning the select columns from the RFE to the model
top_features = df[df['Rank'] == 1]['Column_name']

X_train_top = X_train[top_features]
X_test_top = X_test[top_features]

# %%
# Running the model again
model = LogisticRegression()
model.fit(X_train, Y_train)
result = model.score(X_train, Y_train)
print("The accuracy of the model is = ", round(result,2))

# did not improve the model - keeping the original model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               target_b   R-squared (uncentered):                   0.056
# Model:                            OLS   Adj. R-squared (uncentered):              0.056
# Method:                 Least Squares   F-statistic:                              228.5
# Date:                Fri, 19 Jan 2024   Prob (F-statistic):                        0.00
# Time:                        19:31:12   Log-Likelihood:                          7761.4
# No. Observations:               76329   AIC:                                 -1.548e+04
# Df Residuals:                   76309   BIC:                                 -1.530e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# income         0.0026      0.000      5.699      0.000       0.002       0.004
# pop90c4        0.0120      0.024      0.501      0.616      -0.035       0.059
# pop90c5        0.0119      0.024      0.498      0.619      -0.035       0.059
# eth10          0.0028      0.001      3.500      0.000       0.001       0.004
# dw3           -0.0034      0.002     -2.096      0.036      -0.007      -0.000
# dw5           -0.0034      0.002     -2.115      0.034      -0.007      -0.000
# dw7            0.0024      0.005      0.484      0.628      -0.007       0.012
# dw8           -0.0030      0.005     -0.613      0.540      -0.013       0.007
# dw9           -0.0026      0.005     -0.528      0.597      -0.012       0.007
# hhd5          -0.0120      0.024     -0.498      0.618      -0.059       0.035
# hhd6          -0.0115      0.024     -0.478      0.632      -0.059       0.036
# ethc1          0.0002      0.000      1.376      0.169   -8.98e-05       0.001
# hupa1          0.0033      0.002      2.032      0.042       0.000       0.006
# hupa2          0.0033      0.002      2.063      0.039       0.000       0.007
# tpe3           0.0075      0.004      1.785      0.074      -0.001       0.016
# tpe4          -0.0080      0.004     -1.901      0.057      -0.016       0.000
# tpe5          -0.0076      0.004     -1.801      0.072      -0.016       0.001
# tpe6          -0.0072      0.004     -1.672      0.095      -0.016       0.001
# hc15           0.0027      0.002      1.751      0.080      -0.000       0.006
# rfa_2f         0.0149      0.001     20.506      0.000       0.014       0.016
# ==============================================================================
# Omnibus:                    61299.833   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           889842.590
# Skew:                           4.061   Prob(JB):                         0.00
# Kurtosis:                      17.623   Cond. No.                     6.88e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 6.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # 4. Predictions

# %% [markdown]
# Predictions for 'target_b'

# %%
predictions_target_b = model_b.predict(X_test)

print('Accuracy is: ',  accuracy_score(Y_test, predictions_target_b))
print('Precision is: ', precision_score(Y_test, predictions_target_b))
print('Recall is: ',  recall_score(Y_test, predictions_target_b))
print('F1 is: ',  f1_score(Y_test, predictions_target_b))

print(classification_report(Y_test, predictions_target_b))
# Out:
# Accuracy is:  0.9476497406068228
# Precision is:  0.043478260869565216
# Recall is:  0.0010224948875255625
# F1 is:  0.001998001998001998
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     18105
#            1       0.04      0.00      0.00       978
#
#     accuracy                           0.95     19083
#    macro avg       0.50      0.50      0.49     19083
# weighted avg       0.90      0.95      0.92     19083

# %%
'''
Interpretation:
Eventhough accuracy is hight, due to the high imblance in the data, precision and recall is very low.
I need to handle the imbalance to improve the data.
'''

# %% [markdown]
# # 5. Model for 'target_d'
# Train Data

# %%
# 1. Make predictions on the train set
predictions_target_b_train = model_b.predict(X_train)

# 2. Filter the data for donors
X_train_d = X_train[predictions_target_b_train == 1]
Y_train_d = Y_train[predictions_target_b_train == 1]

# %% [markdown]
# Test Data

# %%
# 1. Make predictions on the test set
predictions_target_b_test = model_b.predict(X_test)

# 2. Filter the data for donors
X_test_d = X_test[predictions_target_b_test == 1]
Y_test_d = Y_test[predictions_target_b_test == 1]

# %%
# 2. Train Regression Model for 'target_d' (linear regression)
model_d = sm.OLS(Y_train_d, X_train_d).fit()
model_d.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               target_b   R-squared (uncentered):                   0.483
# Model:                            OLS   Adj. R-squared (uncentered):              0.200
# Method:                 Least Squares   F-statistic:                              1.707
# Date:                Sat, 20 Jan 2024   Prob (F-statistic):                      0.0452
# Time:                        15:15:26   Log-Likelihood:                          25.382
# No. Observations:                  82   AIC:                                      7.236
# Df Residuals:                      53   BIC:                                      77.03
# Df Model:                          29
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tcode      -9.861e-06   1.94e-05     -0.508      0.614   -4.88e-05    2.91e-05
# age            0.0012      0.006      0.208      0.836      -0.010       0.013
# income         0.1279      0.057      2.250      0.029       0.014       0.242
# wealth1       -0.0612      0.028     -2.201      0.032      -0.117      -0.005
# hit            0.0067      0.039      0.173      0.863      -0.071       0.084
# malemili       0.0033      0.004      0.848      0.400      -0.005       0.011
# malevet        0.0058      0.007      0.793      0.431      -0.009       0.021
# vietvets       0.0003      0.006      0.057      0.954      -0.012       0.012
# wwiivets       0.0011      0.007      0.173      0.863      -0.012       0.014
# localgov      -0.0494      0.028     -1.775      0.082      -0.105       0.006
# stategov       0.0224      0.016      1.411      0.164      -0.009       0.054
# fedgov         0.0055      0.011      0.515      0.609      -0.016       0.027
# wealth2        0.0010      0.015      0.065      0.949      -0.030       0.032
# pop901     -1.033e-14    7.5e-15     -1.376      0.174   -2.54e-14    4.72e-15
# pop902     -1.555e-14   1.12e-14     -1.389      0.170    -3.8e-14     6.9e-15
# pop903     -3.504e-14   2.53e-14     -1.382      0.173   -8.59e-14    1.58e-14
# pop90c1     -4.81e-15   3.43e-15     -1.404      0.166   -1.17e-14    2.06e-15
# pop90c2    -5.217e-15   3.81e-15     -1.368      0.177   -1.29e-14    2.43e-15
# pop90c3     -3.51e-15   2.52e-15     -1.395      0.169   -8.55e-15    1.54e-15
# pop90c4     1.538e-14   1.12e-14      1.375      0.175   -7.06e-15    3.78e-14
# pop90c5     -1.83e-14   1.32e-14     -1.382      0.173   -4.49e-14    8.25e-15
# eth1       -1.701e-14   1.23e-14     -1.380      0.173   -4.17e-14    7.72e-15
# eth2        2.189e-14   1.59e-14      1.379      0.174   -9.96e-15    5.37e-14
# eth3        2.837e-15   2.01e-15      1.408      0.165    -1.2e-15    6.88e-15
# eth4        2.573e-14   1.86e-14      1.382      0.173   -1.16e-14    6.31e-14
# eth5       -1.744e-14   1.28e-14     -1.366      0.178    -4.3e-14    8.16e-15
# eth6       -2.165e-15   1.55e-15     -1.398      0.168   -5.27e-15    9.41e-16
# eth7       -1.705e-15   1.24e-15     -1.373      0.176    -4.2e-15    7.86e-16
# eth8        1.356e-15   9.92e-16      1.366      0.178   -6.34e-16    3.35e-15
# eth9        2.721e-29   1.98e-29      1.373      0.175   -1.25e-29     6.7e-29
# eth10       2.112e-29   1.56e-29      1.358      0.180   -1.01e-29    5.23e-29
# eth11       5.826e-30   4.25e-30      1.371      0.176    -2.7e-30    1.43e-29
# eth12      -2.922e-29   2.11e-29     -1.385      0.172   -7.15e-29    1.31e-29
# eth13      -5.912e-30   4.36e-30     -1.357      0.181   -1.47e-29    2.83e-30
# eth14       7.795e-30   5.62e-30      1.388      0.171   -3.47e-30    1.91e-29
# eth15      -5.682e-30   4.15e-30     -1.371      0.176    -1.4e-29    2.63e-30
# eth16      -9.421e-30   6.75e-30     -1.397      0.168    -2.3e-29    4.11e-30
# age901       1.81e-29   1.31e-29      1.381      0.173   -8.18e-30    4.44e-29
# age902      -1.39e-30      1e-30     -1.390      0.170    -3.4e-30    6.16e-31
# age903      4.915e-32   3.44e-32      1.427      0.160   -1.99e-32    1.18e-31
# age904     -5.309e-31   3.76e-31     -1.411      0.164   -1.29e-30    2.24e-31
# age905     -1.016e-30    7.3e-31     -1.392      0.170   -2.48e-30    4.48e-31
# age906     -1.218e-30   8.84e-31     -1.377      0.174   -2.99e-30    5.55e-31
# age907     -3.243e-30   2.35e-30     -1.379      0.174   -7.96e-30    1.47e-30
# chil1       9.312e-31   6.77e-31      1.375      0.175   -4.27e-31    2.29e-30
# chil2       9.433e-43   6.85e-43      1.377      0.174   -4.31e-43    2.32e-42
# chil3      -6.211e-45   4.43e-45     -1.401      0.167   -1.51e-44    2.68e-45
# agec1      -3.249e-45   2.36e-45     -1.375      0.175   -7.99e-45    1.49e-45
# agec2       2.318e-45   1.69e-45      1.368      0.177   -1.08e-45    5.72e-45
# agec3      -6.278e-45   4.55e-45     -1.379      0.174   -1.54e-44    2.85e-45
# agec4       1.398e-45   1.02e-45      1.372      0.176   -6.46e-46    3.44e-45
# agec5       9.077e-45   6.57e-45      1.382      0.173    -4.1e-45    2.23e-44
# agec6       1.727e-45   1.24e-45      1.396      0.169   -7.54e-46    4.21e-45
# agec7       4.056e-46   2.94e-46      1.379      0.174   -1.84e-46    9.96e-46
# chilc1     -8.807e-46   6.37e-46     -1.382      0.173   -2.16e-45    3.98e-46
# chilc2     -1.548e-45   1.12e-45     -1.380      0.173    -3.8e-45    7.01e-46
# chilc3       3.35e-46   2.45e-46      1.365      0.178   -1.57e-46    8.27e-46
# chilc4     -5.598e-46   4.06e-46     -1.380      0.173   -1.37e-45    2.54e-46
# chilc5      1.659e-46   1.22e-46      1.356      0.181   -7.95e-47    4.11e-46
# hhage1      2.589e-48   1.47e-48      1.760      0.084   -3.61e-49    5.54e-48
# hhage2      6.889e-46   4.99e-46      1.380      0.173   -3.12e-46    1.69e-45
# hhage3      1.778e-57   1.29e-57      1.377      0.174   -8.12e-58    4.37e-57
# hhn1        5.427e-60   3.92e-60      1.385      0.172   -2.43e-60    1.33e-59
# hhn2        -1.02e-59    7.3e-60     -1.398      0.168   -2.48e-59    4.44e-60
# hhn3        9.908e-61   7.15e-61      1.386      0.172   -4.43e-61    2.42e-60
# hhn4        1.247e-61   8.89e-62      1.402      0.167   -5.37e-62    3.03e-61
# hhn5       -1.508e-62   1.13e-62     -1.330      0.189   -3.78e-62    7.67e-63
# hhn6        1.592e-60   1.15e-60      1.380      0.174   -7.23e-61    3.91e-60
# marr1       1.892e-61   1.38e-61      1.367      0.177   -8.83e-62    4.67e-61
# marr2       9.241e-62   6.73e-62      1.373      0.176   -4.26e-62    2.27e-61
# marr3       2.766e-61   2.01e-61      1.379      0.174   -1.26e-61    6.79e-61
# marr4       7.306e-62   5.29e-62      1.382      0.173    -3.3e-62    1.79e-61
# hhp1       -1.041e-61   7.57e-62     -1.374      0.175   -2.56e-61    4.79e-62
# hhp2        1.689e-63    1.2e-63      1.406      0.166   -7.21e-64     4.1e-63
# dw1         2.816e-62   2.04e-62      1.381      0.173   -1.27e-62    6.91e-62
# dw2        -6.138e-66      1e-65     -0.613      0.542   -2.62e-65    1.39e-65
# dw3        -1.065e-62   7.72e-63     -1.380      0.173   -2.61e-62    4.84e-63
# dw4         1.205e-74   8.74e-75      1.380      0.173   -5.47e-75    2.96e-74
# dw5         1.293e-74   9.38e-75      1.379      0.174   -5.88e-75    3.17e-74
# dw6         1.938e-76    1.4e-76      1.379      0.174    -8.8e-77    4.76e-76
# dw7         7.658e-77   5.57e-77      1.374      0.175   -3.52e-77    1.88e-76
# dw8                 0          0        nan        nan           0           0
# dw9                 0          0        nan        nan           0           0
# hv1                 0          0        nan        nan           0           0
# hv2                 0          0        nan        nan           0           0
# hv3                 0          0        nan        nan           0           0
# hv4                 0          0        nan        nan           0           0
# hu1                 0          0        nan        nan           0           0
# hu2                 0          0        nan        nan           0           0
# hu3                 0          0        nan        nan           0           0
# hu4                 0          0        nan        nan           0           0
# hu5                 0          0        nan        nan           0           0
# hhd1                0          0        nan        nan           0           0
# hhd2                0          0        nan        nan           0           0
# hhd3                0          0        nan        nan           0           0
# hhd4                0          0        nan        nan           0           0
# hhd5                0          0        nan        nan           0           0
# hhd6                0          0        nan        nan           0           0
# hhd7                0          0        nan        nan           0           0
# hhd8                0          0        nan        nan           0           0
# hhd9                0          0        nan        nan           0           0
# hhd10               0          0        nan        nan           0           0
# hhd11               0          0        nan        nan           0           0
# hhd12               0          0        nan        nan           0           0
# ethc1               0          0        nan        nan           0           0
# ethc2               0          0        nan        nan           0           0
# ethc3               0          0        nan        nan           0           0
# ethc4               0          0        nan        nan           0           0
# ethc5               0          0        nan        nan           0           0
# ethc6               0          0        nan        nan           0           0
# hvp1                0          0        nan        nan           0           0
# hvp2                0          0        nan        nan           0           0
# hvp3                0          0        nan        nan           0           0
# hvp4                0          0        nan        nan           0           0
# hvp5                0          0        nan        nan           0           0
# hvp6                0          0        nan        nan           0           0
# hur1                0          0        nan        nan           0           0
# hur2                0          0        nan        nan           0           0
# rhp1                0          0        nan        nan           0           0
# rhp2                0          0        nan        nan           0           0
# rhp3                0          0        nan        nan           0           0
# rhp4                0          0        nan        nan           0           0
# hupa1               0          0        nan        nan           0           0
# hupa2               0          0        nan        nan           0           0
# hupa3               0          0        nan        nan           0           0
# hupa4               0          0        nan        nan           0           0
# hupa5               0          0        nan        nan           0           0
# hupa6               0          0        nan        nan           0           0
# hupa7               0          0        nan        nan           0           0
# rp1                 0          0        nan        nan           0           0
# rp2                 0          0        nan        nan           0           0
# rp3                 0          0        nan        nan           0           0
# rp4                 0          0        nan        nan           0           0
# msa                 0          0        nan        nan           0           0
# adi                 0          0        nan        nan           0           0
# dma                 0          0        nan        nan           0           0
# ic1                 0          0        nan        nan           0           0
# ic2                 0          0        nan        nan           0           0
# ic3                 0          0        nan        nan           0           0
# ic4                 0          0        nan        nan           0           0
# ic5                 0          0        nan        nan           0           0
# ic6                 0          0        nan        nan           0           0
# ic7                 0          0        nan        nan           0           0
# ic8                 0          0        nan        nan           0           0
# ic9                 0          0        nan        nan           0           0
# ic10                0          0        nan        nan           0           0
# ic11                0          0        nan        nan           0           0
# ic12                0          0        nan        nan           0           0
# ic13                0          0        nan        nan           0           0
# ic14                0          0        nan        nan           0           0
# ic15                0          0        nan        nan           0           0
# ic16                0          0        nan        nan           0           0
# ic17                0          0        nan        nan           0           0
# ic18                0          0        nan        nan           0           0
# ic19                0          0        nan        nan           0           0
# ic20                0          0        nan        nan           0           0
# ic21                0          0        nan        nan           0           0
# ic22                0          0        nan        nan           0           0
# ic23                0          0        nan        nan           0           0
# hhas1               0          0        nan        nan           0           0
# hhas2               0          0        nan        nan           0           0
# hhas3               0          0        nan        nan           0           0
# hhas4               0          0        nan        nan           0           0
# mc1                 0          0        nan        nan           0           0
# mc2                 0          0        nan        nan           0           0
# mc3                 0          0        nan        nan           0           0
# tpe1                0          0        nan        nan           0           0
# tpe2                0          0        nan        nan           0           0
# tpe3                0          0        nan        nan           0           0
# tpe4                0          0        nan        nan           0           0
# tpe5                0          0        nan        nan           0           0
# tpe6                0          0        nan        nan           0           0
# tpe7                0          0        nan        nan           0           0
# tpe8                0          0        nan        nan           0           0
# tpe9                0          0        nan        nan           0           0
# pec1                0          0        nan        nan           0           0
# pec2                0          0        nan        nan           0           0
# tpe10               0          0        nan        nan           0           0
# tpe11               0          0        nan        nan           0           0
# tpe12               0          0        nan        nan           0           0
# tpe13               0          0        nan        nan           0           0
# lfc1                0          0        nan        nan           0           0
# lfc2                0          0        nan        nan           0           0
# lfc3                0          0        nan        nan           0           0
# lfc4                0          0        nan        nan           0           0
# lfc5                0          0        nan        nan           0           0
# lfc6                0          0        nan        nan           0           0
# lfc7                0          0        nan        nan           0           0
# lfc8                0          0        nan        nan           0           0
# lfc9                0          0        nan        nan           0           0
# lfc10               0          0        nan        nan           0           0
# occ1                0          0        nan        nan           0           0
# occ2                0          0        nan        nan           0           0
# occ3                0          0        nan        nan           0           0
# occ4                0          0        nan        nan           0           0
# occ5                0          0        nan        nan           0           0
# occ6                0          0        nan        nan           0           0
# occ7                0          0        nan        nan           0           0
# occ8                0          0        nan        nan           0           0
# occ9                0          0        nan        nan           0           0
# occ10               0          0        nan        nan           0           0
# occ11               0          0        nan        nan           0           0
# occ12               0          0        nan        nan           0           0
# occ13               0          0        nan        nan           0           0
# eic1                0          0        nan        nan           0           0
# eic2                0          0        nan        nan           0           0
# eic3                0          0        nan        nan           0           0
# eic4                0          0        nan        nan           0           0
# eic5                0          0        nan        nan           0           0
# eic6                0          0        nan        nan           0           0
# eic7                0          0        nan        nan           0           0
# eic8                0          0        nan        nan           0           0
# eic9                0          0        nan        nan           0           0
# eic10               0          0        nan        nan           0           0
# eic11               0          0        nan        nan           0           0
# eic12               0          0        nan        nan           0           0
# eic13               0          0        nan        nan           0           0
# eic14               0          0        nan        nan           0           0
# eic15               0          0        nan        nan           0           0
# eic16               0          0        nan        nan           0           0
# oedc1               0          0        nan        nan           0           0
# oedc2               0          0        nan        nan           0           0
# oedc3               0          0        nan        nan           0           0
# oedc4               0          0        nan        nan           0           0
# oedc5               0          0        nan        nan           0           0
# oedc6               0          0        nan        nan           0           0
# oedc7               0          0        nan        nan           0           0
# ec1                 0          0        nan        nan           0           0
# ec2                 0          0        nan        nan           0           0
# ec3                 0          0        nan        nan           0           0
# ec4                 0          0        nan        nan           0           0
# ec5                 0          0        nan        nan           0           0
# ec6                 0          0        nan        nan           0           0
# ec7                 0          0        nan        nan           0           0
# ec8                 0          0        nan        nan           0           0
# sec1                0          0        nan        nan           0           0
# sec2                0          0        nan        nan           0           0
# sec3                0          0        nan        nan           0           0
# sec4                0          0        nan        nan           0           0
# sec5                0          0        nan        nan           0           0
# afc1                0          0        nan        nan           0           0
# afc2                0          0        nan        nan           0           0
# afc3                0          0        nan        nan           0           0
# afc4                0          0        nan        nan           0           0
# afc5                0          0        nan        nan           0           0
# afc6                0          0        nan        nan           0           0
# vc1                 0          0        nan        nan           0           0
# vc2                 0          0        nan        nan           0           0
# vc3                 0          0        nan        nan           0           0
# vc4                 0          0        nan        nan           0           0
# anc1                0          0        nan        nan           0           0
# anc2                0          0        nan        nan           0           0
# anc3                0          0        nan        nan           0           0
# anc4                0          0        nan        nan           0           0
# anc5                0          0        nan        nan           0           0
# anc6                0          0        nan        nan           0           0
# anc7                0          0        nan        nan           0           0
# anc8                0          0        nan        nan           0           0
# anc9                0          0        nan        nan           0           0
# anc10               0          0        nan        nan           0           0
# anc11               0          0        nan        nan           0           0
# anc12               0          0        nan        nan           0           0
# anc13               0          0        nan        nan           0           0
# anc14               0          0        nan        nan           0           0
# anc15               0          0        nan        nan           0           0
# pobc1               0          0        nan        nan           0           0
# pobc2               0          0        nan        nan           0           0
# lsc1                0          0        nan        nan           0           0
# lsc2                0          0        nan        nan           0           0
# lsc3                0          0        nan        nan           0           0
# lsc4                0          0        nan        nan           0           0
# voc1                0          0        nan        nan           0           0
# voc2                0          0        nan        nan           0           0
# voc3                0          0        nan        nan           0           0
# hc1                 0          0        nan        nan           0           0
# hc2                 0          0        nan        nan           0           0
# hc3                 0          0        nan        nan           0           0
# hc4                 0          0        nan        nan           0           0
# hc5                 0          0        nan        nan           0           0
# hc6                 0          0        nan        nan           0           0
# hc7                 0          0        nan        nan           0           0
# hc8                 0          0        nan        nan           0           0
# hc9                 0          0        nan        nan           0           0
# hc10                0          0        nan        nan           0           0
# hc11                0          0        nan        nan           0           0
# hc12                0          0        nan        nan           0           0
# hc13                0          0        nan        nan           0           0
# hc14                0          0        nan        nan           0           0
# hc15                0          0        nan        nan           0           0
# hc16                0          0        nan        nan           0           0
# hc17                0          0        nan        nan           0           0
# hc18                0          0        nan        nan           0           0
# hc19                0          0        nan        nan           0           0
# hc20                0          0        nan        nan           0           0
# hc21                0          0        nan        nan           0           0
# mhuc1               0          0        nan        nan           0           0
# mhuc2               0          0        nan        nan           0           0
# ac1                 0          0        nan        nan           0           0
# ac2                 0          0        nan        nan           0           0
# cardprom       0.0056      0.034      0.164      0.870      -0.063       0.075
# numprom       -0.0010      0.013     -0.079      0.938      -0.028       0.026
# cardpm12      -0.0986      0.058     -1.691      0.097      -0.216       0.018
# numprm12       0.0294      0.027      1.097      0.277      -0.024       0.083
# ramntall       0.0003      0.001      0.242      0.809      -0.002       0.003
# ngiftall      -0.0020      0.014     -0.140      0.889      -0.030       0.026
# cardgift      -0.0114      0.022     -0.521      0.605      -0.055       0.033
# minramnt       0.0020      0.013      0.153      0.879      -0.024       0.028
# maxramnt       0.0081      0.011      0.725      0.472      -0.014       0.030
# lastgift      -0.0096      0.009     -1.087      0.282      -0.027       0.008
# timelag    -5.079e-05      0.007     -0.008      0.994      -0.013       0.013
# avggift       -0.0069      0.020     -0.342      0.734      -0.047       0.033
# controln    1.174e-07   7.81e-07      0.150      0.881   -1.45e-06    1.68e-06
# hphone_d      -0.0335      0.103     -0.326      0.746      -0.240       0.173
# rfa_2f         0.0214      0.033      0.653      0.517      -0.044       0.087
# cluster2       0.0031      0.003      1.033      0.306      -0.003       0.009
# ==============================================================================
# Omnibus:                       69.085   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              423.018
# Skew:                           2.638   Prob(JB):                     1.39e-92
# Kurtosis:                      12.797   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The input rank is higher than the number of observations.
# [4] The smallest eigenvalue is 1.88e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
predictions_target_d = model_d.predict(X_test_d)

# %%
mse = mean_squared_error(Y_test_d, predictions_target_d)
mae = mean_absolute_error(Y_test_d, predictions_target_d)
print("R2 value is = ",round(r2_score(Y_test_d, predictions_target_d),2))
print("The mse of the model is = ", round(mse,2))
print("The root mse of the model is = ",round(np.sqrt(mse),2))
print("The mean absolute error of the model is = ",round(mae,2))
# Out:
# R2 value is =  -0.8
# The mse of the model is =  0.07
# The root mse of the model is =  0.27
# The mean absolute error of the model is =  0.14

# %% [markdown]
# # 6. Improve Model by dealing with Imbalenced Data

# %% [markdown]
# - SMOTE (Oversampling)

# %%
X = donors.drop(['target_b', 'target_d'], axis = 1)
Y = donors['target_b']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
sm = SMOTE(random_state = 0, sampling_strategy = 1.0)
X_train_SMOTE, Y_train_SMOTE = sm.fit_resample(X_train, Y_train)
X_train_SMOTE

# Build model
model = LogisticRegression(max_iter = 1000)
model.fit(X_train_SMOTE, Y_train_SMOTE)
# Out:
# LogisticRegression(max_iter=1000)

# %%
result = model.score(X_train, Y_train)
print("The accuracy of the model is = ", round(result,2))
# Out:
# The accuracy of the model is =  0.59

# %%
predictions = model.predict(X_train_SMOTE)

print('Accuracy is: ',  accuracy_score(Y_train_SMOTE, predictions))
print('Precision is: ', precision_score(Y_train_SMOTE, predictions))
print('Recall is: ',  recall_score(Y_train_SMOTE, predictions))
print('F1 is: ',  f1_score(Y_train_SMOTE, predictions))

print(classification_report(Y_train_SMOTE, predictions))
# Out:
# Accuracy is:  0.6267042945462574
# Precision is:  0.6182284088128871
# Recall is:  0.6625496798410245
# F1 is:  0.6396221764819515
#               precision    recall  f1-score   support
#
#            0       0.64      0.59      0.61     72464
#            1       0.62      0.66      0.64     72464
#
#     accuracy                           0.63    144928
#    macro avg       0.63      0.63      0.63    144928
# weighted avg       0.63      0.63      0.63    144928

# %% [markdown]
# - TomekLinks (undersampling)

# %%
X = donors.drop(['target_b', 'target_d'], axis = 1)
Y = donors['target_b']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
Y_train_TL.value_counts()
# Out:
# 0    70377
# 1     3865
# Name: target_b, dtype: int64

# %%
tl = TomekLinks()
X_train_TL, Y_train_TL = tl.fit_resample(X_train, Y_train)

# Build model
model = LogisticRegression(max_iter = 1000)
model.fit(X_train_TL, Y_train_TL)
# Out:
# LogisticRegression(max_iter=1000)

# %%
predictions = model.predict(X_train_TL)

print('Accuracy is: ',  accuracy_score(Y_train_TL, predictions))
print('Precision is: ', precision_score(Y_train_TL, predictions))
print('Recall is: ',  recall_score(Y_train_TL, predictions))
print('F1 is: ',  f1_score(Y_train_TL, predictions))

print(classification_report(Y_train_TL, predictions))
# Out:
# Accuracy is:  0.9479001104496108
# Precision is:  0.0
# Recall is:  0.0
# F1 is:  0.0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     70377
#            1       0.00      0.00      0.00      3865
#
#     accuracy                           0.95     74242
#    macro avg       0.47      0.50      0.49     74242
# weighted avg       0.90      0.95      0.92     74242

# %%
Y_train_TL.value_counts()
# Out:
# 0    70377
# 1     3865
# Name: target_b, dtype: int64

# %%
'''
The explanation for the poor improvement of the model lays in this case in the inefficient TomekLinks method.
An imbalance of the data is still given and influences the model greatly.
'''
# Out:
# ''
